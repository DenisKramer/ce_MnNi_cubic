# %% [markdown]
# # Convex Hull

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial import ConvexHull, convex_hull_plot_2d

df=pd.read_fwf('../fit_1/summary.dat',header=0)

points = np.array([[v[0],v[1]] for v in zip(df['comp(a)'],df['formation_energy'])])
hull = ConvexHull(points)

plt.figure(figsize=(12,9))
plt.plot(df['comp(a)'],df['formation_energy'],'x')
for simplex in hull.simplices:

    if not np.all(points[simplex, 1] == 0.0):
        plt.plot(points[simplex, 0], points[simplex, 1], 'ro-')
        
plt
# Out:
# <module 'matplotlib.pyplot' from '/opt/conda/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# # Correlation plot

# %% [markdown]
# ## Full concentration range
# This is a cluster expansion over the full concentration range. Given the complexity of the charge transfer in the system, the quality of the fit is not that great.

# %%
df=pd.read_fwf('../fit_1/summary.dat',header=0)
plt.figure(figsize=(7,7))
plt.plot(df['formation_energy'],df['clex()'],'x')
plt.plot([min(df['formation_energy']),max(df['formation_energy'])],[min(df['formation_energy']),max(df['formation_energy'])],'r-')
plt.xlabel("formation energy DFT [eV]");
plt.ylabel("formation energy CE [eV]");

# %% [markdown]
# ## Mn-rich half-space
# Fit quality can be improved by reducing the considered concentration range.

# %%
df=pd.read_fwf('../fit_2/summary.dat',header=0)
plt.figure(figsize=(7,7))
plt.plot(df['formation_energy'],df['clex()'],'x')
plt.plot([min(df['formation_energy']),max(df['formation_energy'])],[min(df['formation_energy']),max(df['formation_energy'])],'r-')
plt.xlabel("formation energy DFT [eV]");
plt.ylabel("formation energy CE [eV]");

# %% [markdown]
# ## Ni-rich half-space

# %%
df=pd.read_fwf('../fit_3/summary.dat',header=0)
plt.figure(figsize=(7,7))
plt.plot(df['formation_energy'],df['clex()'],'x')
plt.plot([min(df['formation_energy']),max(df['formation_energy'])],[min(df['formation_energy']),max(df['formation_energy'])],'r-')
plt.xlabel("formation energy DFT [eV]");
plt.ylabel("formation energy CE [eV]");

# %%
df
# Out:
#      #           configname  selected   comp(a)  formation_energy    clex()
# 0  NaN  SCEL1_1_1_1_0_0_0/1         1  1.000000         -0.000000  0.045353
# 1  NaN  SCEL2_1_1_2_0_0_0/0         1  0.500000         -0.277938 -0.279104
# 2  NaN  SCEL2_1_2_1_1_0_0/0         1  0.500000         -0.314898 -0.316906
# 3  NaN  SCEL2_2_1_1_0_1_1/0         1  0.500000         -0.445750 -0.401620
# 4  NaN  SCEL3_1_1_3_0_0_0/1         1  0.666667         -0.189830 -0.223802
# 5  NaN  SCEL3_1_3_1_1_0_0/1         1  0.666667         -0.227073 -0.240421
# 6  NaN  SCEL3_3_1_1_0_1_1/1         1  0.666667         -0.265281 -0.282451
# 7  NaN  SCEL4_1_1_4_0_0_0/1         1  0.500000         -0.212593 -0.203741
# 8  NaN  SCEL4_1_1_4_0_0_0/2         1  0.750000         -0.145270 -0.156514
# 9  NaN  SCEL4_1_2_2_0_0_0/1         1  0.750000         -0.169072 -0.191862
# 10 NaN  SCEL4_1_4_1_1_0_0/1         1  0.500000         -0.255737 -0.270963
# 11 NaN  SCEL4_1_4_1_1_0_0/2         1  0.750000         -0.173677 -0.193683
# 12 NaN  SCEL4_1_4_1_2_0_0/1         1  0.500000         -0.303467 -0.278457
# 13 NaN  SCEL4_1_4_1_2_0_0/2         1  0.750000         -0.171805 -0.182088
# 14 NaN  SCEL4_2_1_2_0_0_1/1         1  0.750000         -0.214154 -0.234274
# 15 NaN  SCEL4_2_1_2_0_1_1/1         1  0.500000         -0.386088 -0.351884
# 16 NaN  SCEL4_2_1_2_0_1_1/2         1  0.750000         -0.204372 -0.230585
# 17 NaN  SCEL4_2_2_1_1_0_1/1         1  0.500000         -0.347511 -0.301707
# 18 NaN  SCEL4_2_2_1_1_0_1/2         1  0.750000         -0.198257 -0.209056
# 19 NaN  SCEL4_2_2_1_1_1_0/1         1  0.750000         -0.198514 -0.210763
# 20 NaN  SCEL4_4_1_1_0_3_3/1         1  0.500000         -0.291368 -0.294535
# 21 NaN  SCEL4_4_1_1_0_3_3/2         1  0.750000         -0.219308 -0.232540
# 22 NaN  SCEL5_1_1_5_0_0_0/3         1  0.600000         -0.189681 -0.153922
# 23 NaN  SCEL5_1_1_5_0_0_0/4         1  0.600000         -0.225325 -0.245923
# 24 NaN  SCEL5_1_1_5_0_0_0/5         1  0.800000         -0.111260 -0.116140
# 25 NaN  SCEL5_1_5_1_2_0_0/2         1  0.600000         -0.262008 -0.257957
# 26 NaN  SCEL5_1_5_1_2_0_0/3         1  0.800000         -0.144172 -0.148546
# 27 NaN  SCEL5_1_5_1_4_0_0/3         1  0.600000         -0.227756 -0.227465
# 28 NaN  SCEL5_1_5_1_4_0_0/4         1  0.600000         -0.265914 -0.271015
# 29 NaN  SCEL5_1_5_1_4_0_0/5         1  0.800000         -0.137412 -0.145876
# ..  ..                  ...       ...       ...               ...       ...
# 70 NaN  SCEL6_3_1_2_0_2_1/3         1  0.500000         -0.310474 -0.296191
# 71 NaN  SCEL6_3_1_2_0_2_1/4         1  0.500000         -0.343020 -0.315454
# 72 NaN  SCEL6_3_1_2_0_2_1/5         1  0.666667         -0.253058 -0.259261
# 73 NaN  SCEL6_3_1_2_0_2_1/6         1  0.666667         -0.249341 -0.250717
# 74 NaN  SCEL6_3_1_2_0_2_1/7         1  0.833333         -0.140441 -0.142565
# 75 NaN  SCEL6_3_2_1_0_1_0/3         1  0.500000         -0.369362 -0.339068
# 76 NaN  SCEL6_3_2_1_0_1_0/4         1  0.500000         -0.311459 -0.300542
# 77 NaN  SCEL6_3_2_1_0_1_0/5         1  0.666667         -0.268716 -0.286802
# 78 NaN  SCEL6_3_2_1_0_1_0/6         1  0.666667         -0.257585 -0.252892
# 79 NaN  SCEL6_3_2_1_0_1_0/7         1  0.833333         -0.142320 -0.144740
# 80 NaN  SCEL6_3_2_1_1_1_0/3         1  0.500000         -0.333979 -0.306774
# 81 NaN  SCEL6_3_2_1_1_1_0/4         1  0.500000         -0.309790 -0.295619
# 82 NaN  SCEL6_3_2_1_1_1_0/5         1  0.666667         -0.254963 -0.255503
# 83 NaN  SCEL6_3_2_1_1_1_0/6         1  0.666667         -0.261163 -0.256642
# 84 NaN  SCEL6_3_2_1_1_1_0/7         1  0.833333         -0.140860 -0.135889
# 85 NaN  SCEL6_6_1_1_0_4_1/3         1  0.500000         -0.277045 -0.285943
# 86 NaN  SCEL6_6_1_1_0_4_1/4         1  0.500000         -0.345361 -0.316042
# 87 NaN  SCEL6_6_1_1_0_4_1/5         1  0.666667         -0.244180 -0.248424
# 88 NaN  SCEL6_6_1_1_0_4_1/6         1  0.666667         -0.261859 -0.263906
# 89 NaN  SCEL6_6_1_1_0_4_1/7         1  0.833333         -0.142705 -0.143153
# 90 NaN  SCEL6_6_1_1_0_5_3/3         1  0.500000         -0.307236 -0.290116
# 91 NaN  SCEL6_6_1_1_0_5_3/4         1  0.500000         -0.310429 -0.298514
# 92 NaN  SCEL6_6_1_1_0_5_3/5         1  0.666667         -0.249483 -0.232023
# 93 NaN  SCEL6_6_1_1_0_5_3/6         1  0.666667         -0.295323 -0.299558
# 94 NaN  SCEL6_6_1_1_0_5_3/7         1  0.833333         -0.146187 -0.142712
# 95 NaN  SCEL6_6_1_1_0_5_5/3         1  0.500000         -0.237543 -0.256767
# 96 NaN  SCEL6_6_1_1_0_5_5/4         1  0.500000         -0.333240 -0.315808
# 97 NaN  SCEL6_6_1_1_0_5_5/5         1  0.666667         -0.224072 -0.223410
# 98 NaN  SCEL6_6_1_1_0_5_5/6         1  0.666667         -0.291660 -0.295837
# 99 NaN  SCEL6_6_1_1_0_5_5/7         1  0.833333         -0.144091 -0.146846
#
# [100 rows x 6 columns]
